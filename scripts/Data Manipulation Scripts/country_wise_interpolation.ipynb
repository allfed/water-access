# %%
import pandas as pd
import numpy as np
from countryinfo import CountryInfo
import pycountry
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from countryinfo import CountryInfo
#
# File ~/opt/miniconda3/envs/water-access/lib/python3.9/site-packages/pandas/__init__.py:11
#       9 for dependency in hard_dependencies:
#      10     try:
# ---> 11         __import__(dependency)
#      12     except ImportError as e:
#      13         missing_dependencies.append(f"{dependency}: {e}")
#
# File ~/opt/miniconda3/envs/water-access/lib/python3.9/site-packages/numpy/__init__.py:150
#     147 # Allow distributors to run custom init code
#     148 from . import _distributor_init
# --> 150 from . import core
#     151 from .core import *
#     152 from . import compat
#
# File ~/opt/miniconda3/envs/water-access/lib/python3.9/site-packages/numpy/core/__init__.py:22
#      19         env_added.append(envkey)
#      21 try:
# ---> 22     from . import multiarray
#      23 except ImportError as exc:
#      24     import sys
#
# File ~/opt/miniconda3/envs/water-access/lib/python3.9/site-packages/numpy/core/multiarray.py:12
#       9 import functools
#      10 import warnings
# ---> 12 from . import overrides
#      13 from . import _multiarray_umath
#      14 from ._multiarray_umath import *  # noqa: F403
#
# File ~/opt/miniconda3/envs/water-access/lib/python3.9/site-packages/numpy/core/overrides.py:7
#       4 import os
#       5 import textwrap
# ----> 7 from numpy.core._multiarray_umath import (
#       8     add_docstring, implement_array_function, _get_implementing_args)
#       9 from numpy.compat._inspect import getargspec
#      12 ARRAY_FUNCTION_ENABLED = bool(
#      13     int(os.environ.get('NUMPY_EXPERIMENTAL_ARRAY_FUNCTION', 1)))
#
# KeyboardInterrupt:

# %%
def add_alpha_codes_from_ISO(df, col):
    """
    adds a column of alpha3 codes to a dataframe with country name in column 'col'
    """
    input_countries = df[col]
    countries = []
    for input_country in input_countries:
        try:
            country = pycountry.countries.get(alpha_3=input_country)
            alpha2 = country.alpha_2
        except:
            alpha2 = "unk_" + str(input_country)
        countries.append(alpha2)
    df["alpha2"] = countries
    return df

# %%
df_input = pd.read_csv("../data/country_data_master.csv")
# df_input = pd.read_csv("../data/country_data_master.csv", index_col="alpha3")

# %%
iso_num_col = "ISO Code"
col = "Country"
alpha3_col = "alpha3"
alpha2_col = "alpha2"
df_original = df_input



df = add_alpha_codes_from_ISO(df_original, alpha3_col)

# filename = "scratch_new_country_data"
# df.to_csv(filename + ".csv")

# %% [markdown]
# Cell below appends the region, subregion, and bordering countries to the country. This is for future use for interpolation.

# %%
input_countries = df[alpha2_col]
bordering_countries = []
region = []
subregion = []
for input_country in input_countries:
    try:
        country = CountryInfo(input_country)
    except:
        print("couldn't find country")

    try:
        country_bordering_countries = ",".join(str(x) for x in country.borders())
    except:
        country_bordering_countries = "unk_" + str(input_country)
    
    try:
        country_region = country.region()
    except:
        country_region = "unk_" + str(input_country)

    try:
        country_subregion = country.subregion()
    except:
        country_subregion = "unk_" + str(input_country)
    


    
    bordering_countries.append(country_bordering_countries)
    region.append(country_region)
    subregion.append(country_subregion)
df["borders"] = bordering_countries
df["region"] = region
df["subregion"] = subregion

# write csv to ("../data/Country Data before Interp.csv")
df.to_csv("../data/Country Data before Interp.csv")

# %% [markdown]
# Loop over all the variables to interpolate, find a NaN, and then use the three staged interpolation process:
# 1. Take an average of all the bordering countries (if those countries have a value that could be used)
# 2. Take an average of the countries in that sub region
# 3. Take an average of the countries in the region (continent)

# %%
# alternative entry point given exisiting data
df_borders = pd.read_csv("../data/processed/country_borders.csv", index_col="alpha3")

df = pd.read_csv("../data/processed/WHO_JMP_alpha_Codes_processed.csv", index_col="alpha3")

df_countries = pd.read_csv("../data/country_data_master_interpolated.csv", index_col="alpha3")

# keep only the countries country_data_master_interpolated.csv
# drop all columns, only keep the index
df_countries = df_countries.drop(df_countries.columns, axis=1)

# merge df with df countries, only keep those countries in master
df = df.merge(df_countries, how="right", left_index=True, right_index=True)

# %%
df_borders
# Out:
#               Entity alpha2    region        subregion  \
# alpha3
# ABW            Aruba     AW  Americas        Caribbean
# AFG      Afghanistan     AF      Asia    Southern Asia
# AGO           Angola     AO    Africa    Middle Africa
# AIA         Anguilla     AI  Americas        Caribbean
# ALB          Albania     AL    Europe  Southern Europe
# ...              ...    ...       ...              ...
# WSM            Samoa     WS   Oceania        Polynesia
# YEM            Yemen     YE      Asia     Western Asia
# ZAF     South Africa     ZA    Africa  Southern Africa
# ZMB           Zambia     ZM    Africa   Eastern Africa
# ZWE         Zimbabwe     ZW    Africa   Eastern Africa
#
#                                 borders
# alpha3
# ABW                                 NaN
# AFG             IRN,PAK,TKM,UZB,TJK,CHN
# AGO                     COG,COD,ZMB,NAM
# AIA                                 NaN
# ALB                         MNE,GRC,MKD
# ...                                 ...
# WSM                                 NaN
# YEM                             OMN,SAU
# ZAF             BWA,LSO,MOZ,NAM,SWZ,ZWE
# ZMB     AGO,BWA,COD,MWI,MOZ,NAM,TZA,ZWE
# ZWE                     BWA,MOZ,ZAF,ZMB
#
# [234 rows x 5 columns]

# %%
list_of_vars = ['PBO',
       'Terrain Ruggedness', 'Urban %', 'Urban Agg %', 'RoadQuality', 'Km',
       'Urb %', 'Average household size (number of members)',
       'National At Least Basic', 'National Limit (more than 30 mins)',
       'National Unimproved', 'National Surface Water',
       'Nat Accesible On Premises', 'Nat Piped', 'Nat NonPiped','Average Weight','percent_insufficient_activity']

list_of_vars = ['% urban', 'TOTALUnimproved', 'RURALUnimproved', 'URBANUnimproved',       
       'TOTALPiped', 'TOTALNon-piped', 'RURALPiped', 'RURALNon-piped', 'URBANPiped', 'URBANNon-piped']


alpha2_col = "alpha2"
alpha3_col = "alpha3"

df_input = df.merge(df_borders, how="left", on=alpha3_col)
# set index to alpha3

df_output = df_input

df_interp_track = pd.DataFrame(df_input.index)
#set index to alpha3
df_interp_track = df_interp_track.set_index(alpha3_col)
df_interp_track[list_of_vars]="none"

for variable in list_of_vars:
    # convert column to float
    df_input[variable] = df_input[variable].astype(float)

    ## for loop in the future
    #find location of nan values
    nan_locations = df_input[variable].isna()
    countries_requiring_interp = df_input[nan_locations].index

    #next for loop goes here 
    for country in countries_requiring_interp:
        #see if the borders can be used to interpolate
        borders = df_input.loc[country, "borders"]
        borders = str(borders)
        border_list = borders.split(",")
        try:
            avg_var_border = (df_input.loc[border_list, variable].mean())
        except:
            avg_var_border = np.nan
        # see if the subregion can be used to interpolate
        # find other countries in the subregion
        subregion_list = df_input[df_input["subregion"]==df_input.loc[country, "subregion"]].index
        avg_var_subregion = (df_input.loc[subregion_list, variable].mean())
        # assume the region CAN be used to interpolate
        region_list = df_input[df_input["region"]==df_input.loc[country, "region"]].index
        avg_var_region = (df_input.loc[region_list, variable].mean())
        # try border, then subregion, then region
        if ~np.isnan(avg_var_border):
            df_output.loc[country, variable] = avg_var_border
            df_interp_track.loc[country, variable] = "border interpolated"
        elif ~np.isnan(avg_var_subregion):
            df_output.loc[country, variable] = avg_var_subregion
            df_interp_track.loc[country, variable] = "subregion interpolated"
        else:
            df_output.loc[country, variable] = avg_var_region
            df_interp_track.loc[country, variable] = "region interpolated"

# %%
df_input.head(30)
# Out:
#         Unnamed: 0                           Country     % urban  \
# alpha3
# ABW            NaN                               NaN   65.470588
# AFG            0.0                       Afghanistan   27.000000
# AGO            4.0                            Angola   68.000000
# AIA            5.0                          Anguilla  100.000000
# ALB            1.0                           Albania   64.000000
# AND            3.0                           Andorra   88.000000
# ARE          200.0              United Arab Emirates   88.000000
# ARG            7.0                         Argentina   92.000000
# ARM            8.0                           Armenia   64.000000
# ASM            NaN                               NaN   36.625000
# ATG            6.0               Antigua and Barbuda   24.000000
# AUS            9.0                         Australia   86.000000
# AUT           10.0                           Austria   59.000000
# AZE           11.0                        Azerbaijan   57.000000
# BDI           30.0                           Burundi   14.000000
# BEL           16.0                           Belgium   98.000000
# BEN           18.0                             Benin   50.000000
# BES           22.0  Bonaire, Sint Eustatius and Saba   75.000000
# BFA           29.0                      Burkina Faso   32.000000
# BGD           13.0                        Bangladesh   40.000000
# BGR           28.0                          Bulgaria   76.000000
# BHR           12.0                           Bahrain   90.000000
# BHS            NaN                               NaN   65.470588
# BIH           23.0            Bosnia and Herzegovina   50.000000
# BLR           15.0                           Belarus   80.000000
# BLZ           17.0                            Belize   46.000000
# BMU           19.0                           Bermuda  100.000000
# BOL           21.0  Bolivia (Plurinational State of)   71.000000
# BRA           25.0                            Brazil   88.000000
# BRB           14.0                          Barbados   31.000000
#
#         TOTALUnimproved  RURALUnimproved  URBANUnimproved  TOTALPiped  \
# alpha3
# ABW            2.222222         7.714286         2.000000   87.777778
# AFG           10.000000        14.000000         0.000000   23.000000
# AGO           19.000000        23.000000        18.000000   43.000000
# AIA            3.000000         7.714286         3.000000  100.000000
# ALB            3.000000         4.000000         3.000000   81.000000
# AND            0.000000         0.000000         0.000000  100.000000
# ARE            0.000000         0.000000         0.000000  100.000000
# ARG            0.000000         3.000000         0.000000   96.000000
# ARM            0.000000         0.000000         0.000000  100.000000
# ARE           0.000000             United Arab Emirates     AE      Asia
# ARG           0.000000                        Argentina     AR  Americas
# ARM           0.000000                          Armenia     AM      Asia
# ASM           2.000000                   American Samoa     AS   Oceania
# ATG           0.000000              Antigua and Barbuda     AG  Americas
# AUS           0.000000                        Australia     AU   Oceania
# AUT           0.600000                          Austria     AT    Europe
# AZE           0.000000                       Azerbaijan     AZ      Asia
# BDI           8.000000                          Burundi     BI    Africa
# BEL           0.000000                          Belgium     BE    Europe
# BEN          32.000000                            Benin     BJ    Africa
# BES          16.900000  Bonaire Sint Eustatius and Saba     BQ  Americas
# BFA          17.000000                     Burkina Faso     BF    Africa
# BGD          67.000000                       Bangladesh     BD      Asia
# BGR           0.000000                         Bulgaria     BG    Europe
# BHR          10.384615                          Bahrain     BH      Asia
# BHS          16.900000                          Bahamas     BS  Americas
# BIH           2.000000           Bosnia and Herzegovina     BA    Europe
# BLR           0.000000                          Belarus     BY    Europe
# BLZ           4.000000                           Belize     BZ  Americas
# BMU           0.000000                          Bermuda     BM  Americas
# BOL          14.000000                          Bolivia     BO  Americas
# BRA           0.000000                           Brazil     BR  Americas
# BRB          16.900000                         Barbados     BB  Americas
#
#                         subregion                                  borders
# alpha3
# ABW                     Caribbean                                      NaN
# AFG                 Southern Asia                  IRN,PAK,TKM,UZB,TJK,CHN
# AGO                 Middle Africa                          COG,COD,ZMB,NAM
# AIA                     Caribbean                                      NaN
# ALB               Southern Europe                              MNE,GRC,MKD
# AND               Southern Europe                                  FRA,ESP
# ARE                  Western Asia                                  OMN,SAU
# ARG                 South America                      BOL,BRA,CHL,PRY,URY
# ARM                  Western Asia                          AZE,GEO,IRN,TUR
# ASM                     Polynesia                                      NaN
# ATG                     Caribbean                                      NaN
# AUS     Australia and New Zealand                                      NaN
# AUT                Western Europe          CZE,DEU,HUN,ITA,LIE,SVK,SVN,CHE
# AZE                  Western Asia                      ARM,GEO,IRN,RUS,TUR
# BDI                Eastern Africa                              COD,RWA,TZA
# BEL                Western Europe                          FRA,DEU,LUX,NLD
# BEN                Western Africa                          BFA,NER,NGA,TGO
# BES                     Caribbean                                      NaN
# BFA                Western Africa                  BEN,CIV,GHA,MLI,NER,TGO
# BGD                 Southern Asia                                  MMR,IND
# BGR                Eastern Europe                      GRC,MKD,ROU,SRB,TUR
# BHR                  Western Asia                                      NaN
# BHS                     Caribbean                                      NaN
# BIH               Southern Europe                              HRV,MNE,SRB
# BLR                Eastern Europe                      LVA,LTU,POL,RUS,UKR
# BLZ               Central America                                  GTM,MEX
# BMU              Northern America                                      NaN
# BOL                 South America                      ARG,BRA,CHL,PRY,PER
# BRA                 South America  ARG,BOL,COL,GUF,GUY,PRY,PER,SUR,URY,VEN
# BRB                     Caribbean                                      NaN

# %% [markdown]
# Save dataframes as CSV

# %%
# df_input[variable].isna()


filename = "WHOinterpTrack3"
df_interp_track.to_csv(filename + ".csv")
filename = "WHOinterp3"
df_output.to_csv(filename + ".csv")
